# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
import random
from sklearn.decomposition import PCA

# %%
from keras.datasets import cifar10

# %%
#importing dataset
import cv2
import os
import matplotlib.pyplot as plt



pathTrain='C:\\Users\\HAMROUA\\Desktop\\BackupDesktop\\Desktop\\Autoencoder-image-similarity-master\\dataset\\train\\';
all_images = []
subjects = os.listdir(pathTrain)
numberOfSubject = len(subjects)
print('Number of train photos: ', numberOfSubject)
for number1 in range(0, numberOfSubject):  # numberOfSubject
    path3 = pathTrain + subjects[number1]
    img = cv2.imread(path3 , 1)
    img = cv2.resize(img,(32, 32))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    all_images.append(img)
X_train = np.array(all_images)



pathTest='C:\\Users\\HAMROUA\\Desktop\\BackupDesktop\\Desktop\\Autoencoder-image-similarity-master\\dataset\\test\\';
all_images = []
subjects = os.listdir(pathTest)
numberOfSubject = len(subjects)
print('Number of test photos: ', numberOfSubject)
for number1 in range(0, numberOfSubject):  # numberOfSubject
    path3 = pathTest + subjects[number1]
    img = cv2.imread(path3 , 1)
    img = cv2.resize(img,(32, 32))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    all_images.append(img)
X_test = np.array(all_images)



#X_train = np.reshape(x_train, (len(x_train), 32, 32, 3)) / 255.
#X_test = np.reshape(x_test, (len(x_test), 32, 32, 3)) / 255.
# Out:
# Number of train photos:  860
# Number of test photos:  244

# %%
(X_train,Y_train),(X_test,Y_test) = cifar10.load_data()
print(type(X_train))
print(type(x_train))

print(X_train.shape)
print(x_train.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (50000, 32, 32, 3)
# (860, 32, 32, 3)

# %%
pathTest='C:\\Users\\HAMROUA\\Desktop\\Autoencoder-image-similarity-master\\dataset\\test\\';
all_images = []
subjects = os.listdir(pathTest)
numberOfSubject = len(subjects)
print('Number of test photos: ', numberOfSubject)
for number1 in range(0, numberOfSubject):  # numberOfSubject
    path3 = pathTest + subjects[number1]
    img = cv2.imread(path3 , 1)
    img = cv2.resize(img,(32, 32))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    all_images.append(img)
X_test = np.array(all_images)
X_test = X_test.astype('float32')
X_test/=255
# Out:
# Number of test photos:  277

# %%
#Standardise the data
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train/=255 
X_test/=255

# %% [markdown]
# # Model Training

# %%
#Model
#encoder
input_img = tf.keras.layers.Input(shape=(32, 32, 3))

encoder = tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',kernel_initializer='he_normal')(input_img)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',kernel_initializer='he_normal',kernel_regularizer=tf.keras.regularizers.l2(0.008))(encoder)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2)(encoder)
encoder = tf.keras.layers.Dropout(0.5)(encoder)

encoder = tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',kernel_initializer='he_normal',kernel_regularizer=tf.keras.regularizers.l2(0.008))(encoder)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',kernel_initializer='he_normal',kernel_regularizer=tf.keras.regularizers.l2(0.008))(encoder)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2)(encoder)
encoder = tf.keras.layers.Dropout(0.5)(encoder)

encoder = tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding='same',kernel_initializer='he_uniform')(encoder)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding='same',kernel_initializer='he_uniform')(encoder)
encoder = tf.keras.layers.Activation('relu')(encoder)
encoder = tf.keras.layers.BatchNormalization()(encoder)

encoder = tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2)(encoder)
encoder = tf.keras.layers.Dropout(0.5)(encoder)

encoder = tf.keras.layers.Flatten()(encoder)
encoder = tf.keras.layers.Dense(256,activation='relu',kernel_initializer='he_uniform')(encoder)
encoder_out = tf.keras.layers.Dense(256,activation='relu',kernel_initializer='he_uniform')(encoder)

#decoder
decoder_mul = tf.keras.layers.Dense(4*4*128)(encoder_out)
decoder_reshape = tf.keras.layers.Reshape((4,4,128))(decoder_mul)
decoder = tf.keras.layers.Conv2DTranspose(filters=128, kernel_size=(3,3), strides=2, activation='relu', padding='same')(decoder_reshape)
decoder = tf.keras.layers.BatchNormalization()(decoder)
decoder = tf.keras.layers.Dropout(0.5)(decoder)
decoder = tf.keras.layers.Conv2DTranspose(filters=64, kernel_size=(3,3), strides=2, activation='relu', padding='same')(decoder)
decoder = tf.keras.layers.BatchNormalization()(decoder)
decoder = tf.keras.layers.Dropout(0.5)(decoder)
decoder = tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=(3,3), strides=2, activation='relu', padding='same')(decoder)
decoder = tf.keras.layers.BatchNormalization()(decoder)
decoder = tf.keras.layers.Conv2DTranspose(filters=3, kernel_size=(3,3), strides=1, activation=None, padding='same')(decoder)
decoder = tf.keras.layers.Activation('sigmoid')(decoder)

# %%
autoencoder = tf.keras.models.Model(input_img, decoder)
encoder = tf.keras.models.Model(input_img, encoder)
encoded_input = tf.keras.layers.Input(shape=(4, 4, 128))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input,decoder_layer(encoded_input))

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              526336
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 64)        73792
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 32)        18464
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 3)         867
# _________________________________________________________________
# activation_6 (Activation)    multiple                  0
# =================================================================
# Total params: 1,647,075
# Trainable params: 1,645,731
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
autoencoder.compile(loss='mean_squared_error', optimizer='Adam')
history = autoencoder.fit(X_train,X_train,validation_data=(X_test, X_test),batch_size=512,epochs=1000)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 5s 2s/step - loss: 2.6987 - val_loss: 2.5535
# Epoch 2/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.5589 - val_loss: 2.4682
# Epoch 3/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.4348 - val_loss: 2.4063
# Epoch 4/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.3208 - val_loss: 2.3184
# Epoch 5/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.2130 - val_loss: 2.2084
# Epoch 6/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.1093 - val_loss: 2.0987
# Epoch 7/500
# 2/2 [==============================] - 4s 2s/step - loss: 2.0088 - val_loss: 2.0060
# Epoch 8/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.9126 - val_loss: 1.9308
# Epoch 9/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.8203 - val_loss: 1.8649
# Epoch 10/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.7322 - val_loss: 1.8000
# Epoch 11/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.6497 - val_loss: 1.7254
# Epoch 12/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.5725 - val_loss: 1.6363
# Epoch 13/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.4999 - val_loss: 1.5428
# Epoch 14/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.4300 - val_loss: 1.4531
# Epoch 15/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.3635 - val_loss: 1.3663
# Epoch 16/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.3006 - val_loss: 1.2941
# Epoch 17/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.2409 - val_loss: 1.2263
# Epoch 18/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.1841 - val_loss: 1.1660
# Epoch 19/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.1295 - val_loss: 1.1182
# Epoch 20/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.0775 - val_loss: 1.0844
# Epoch 21/500
# 2/2 [==============================] - 4s 2s/step - loss: 1.0282 - val_loss: 1.0043
# Epoch 22/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.9810 - val_loss: 0.9611
# Epoch 23/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.9356 - val_loss: 0.9171
# Epoch 24/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.8926 - val_loss: 0.8759
# Epoch 25/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.8514 - val_loss: 0.8374
# Epoch 26/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.8119 - val_loss: 0.8006
# Epoch 27/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.7743 - val_loss: 0.7659
# Epoch 28/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.7369 - val_loss: 0.7331
# Epoch 29/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.7028 - val_loss: 0.7020
# Epoch 30/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.6705 - val_loss: 0.6722
# Epoch 31/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.6386 - val_loss: 0.6435
# Epoch 32/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.6091 - val_loss: 0.6162
# Epoch 33/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.5811 - val_loss: 0.5902
# Epoch 34/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.5543 - val_loss: 0.5661
# Epoch 35/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.5292 - val_loss: 0.5423
# Epoch 36/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.5045 - val_loss: 0.5200
# Epoch 37/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.4818 - val_loss: 0.4987
# Epoch 38/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.4601 - val_loss: 0.4790
# Epoch 39/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.4400 - val_loss: 0.4593
# Epoch 40/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.4204 - val_loss: 0.4439
# Epoch 41/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.4016 - val_loss: 0.4252
# Epoch 42/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3842 - val_loss: 0.4088
# Epoch 43/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3667 - val_loss: 0.3938
# Epoch 44/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3507 - val_loss: 0.3777
# Epoch 45/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3354 - val_loss: 0.3657
# Epoch 46/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3209 - val_loss: 0.3515
# Epoch 47/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.3066 - val_loss: 0.3386
# Epoch 48/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2935 - val_loss: 0.3290
# Epoch 49/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2809 - val_loss: 0.3164
# Epoch 50/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2690 - val_loss: 0.3050
# Epoch 51/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2571 - val_loss: 0.2958
# Epoch 52/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2466 - val_loss: 0.2850
# Epoch 53/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2360 - val_loss: 0.2770
# Epoch 54/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2257 - val_loss: 0.2695
# Epoch 55/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2161 - val_loss: 0.2615
# Epoch 56/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.2068 - val_loss: 0.2551
# Epoch 57/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1983 - val_loss: 0.2480
# Epoch 58/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1899 - val_loss: 0.2398
# Epoch 59/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1822 - val_loss: 0.2339
# Epoch 60/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1743 - val_loss: 0.2254
# Epoch 61/500
# 2/2 [==============================] - 5s 2s/step - loss: 0.1673 - val_loss: 0.2176
# Epoch 62/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1609 - val_loss: 0.2100
# Epoch 63/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1546 - val_loss: 0.2049
# Epoch 64/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1482 - val_loss: 0.1994
# Epoch 65/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1426 - val_loss: 0.1916
# Epoch 66/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1363 - val_loss: 0.1864
# Epoch 67/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1309 - val_loss: 0.1816
# Epoch 68/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1258 - val_loss: 0.1760
# Epoch 69/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1208 - val_loss: 0.1718
# Epoch 70/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1162 - val_loss: 0.1683
# Epoch 71/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1118 - val_loss: 0.1643
# Epoch 72/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1075 - val_loss: 0.1595
# Epoch 73/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1037 - val_loss: 0.1564
# Epoch 74/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.1001 - val_loss: 0.1523
# Epoch 75/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0970 - val_loss: 0.1499
# Epoch 76/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0932 - val_loss: 0.1486
# Epoch 77/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0899 - val_loss: 0.1453
# Epoch 78/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0871 - val_loss: 0.1433
# Epoch 79/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0840 - val_loss: 0.1400
# Epoch 80/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0811 - val_loss: 0.1380
# Epoch 81/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0784 - val_loss: 0.1346
# Epoch 82/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0754 - val_loss: 0.1313
# Epoch 83/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0733 - val_loss: 0.1296
# Epoch 84/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0709 - val_loss: 0.1275
# Epoch 85/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0682 - val_loss: 0.1253
# Epoch 86/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0661 - val_loss: 0.1230
# Epoch 87/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0639 - val_loss: 0.1204
# Epoch 88/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0617 - val_loss: 0.1184
# Epoch 89/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0602 - val_loss: 0.1174
# Epoch 90/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0585 - val_loss: 0.1155
# Epoch 91/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0570 - val_loss: 0.1124
# Epoch 92/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0562 - val_loss: 0.1127
# Epoch 93/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0547 - val_loss: 0.1098
# Epoch 94/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0529 - val_loss: 0.1093
# Epoch 95/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0520 - val_loss: 0.1068
# Epoch 96/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0502 - val_loss: 0.1051
# Epoch 97/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0488 - val_loss: 0.1042
# Epoch 98/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0479 - val_loss: 0.1017
# Epoch 99/500
# 2/2 [==============================] - 5s 2s/step - loss: 0.0469 - val_loss: 0.1022
# Epoch 100/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0455 - val_loss: 0.1017
# Epoch 101/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0444 - val_loss: 0.1002
# Epoch 102/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0437 - val_loss: 0.0975
# Epoch 103/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0427 - val_loss: 0.0975
# Epoch 104/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0420 - val_loss: 0.0957
# Epoch 105/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0405 - val_loss: 0.0953
# Epoch 106/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0399 - val_loss: 0.0944
# Epoch 107/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0390 - val_loss: 0.0954
# Epoch 108/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0383 - val_loss: 0.0936
# Epoch 109/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0376 - val_loss: 0.0931
# Epoch 110/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0369 - val_loss: 0.0928
# Epoch 111/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0360 - val_loss: 0.0918
# Epoch 112/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0355 - val_loss: 0.0905
# Epoch 113/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0349 - val_loss: 0.0894
# Epoch 114/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0344 - val_loss: 0.0891
# Epoch 115/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0344 - val_loss: 0.0883
# Epoch 116/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0330 - val_loss: 0.0872
# Epoch 117/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0328 - val_loss: 0.0864
# Epoch 118/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0323 - val_loss: 0.0867
# Epoch 119/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0319 - val_loss: 0.0861
# Epoch 120/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0311 - val_loss: 0.0856
# Epoch 121/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0308 - val_loss: 0.0860
# Epoch 122/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0301 - val_loss: 0.0846
# Epoch 123/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0298 - val_loss: 0.0843
# Epoch 124/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0294 - val_loss: 0.0843
# Epoch 125/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0292 - val_loss: 0.0828
# Epoch 126/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0288 - val_loss: 0.0834
# Epoch 127/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.
500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0220 - val_loss: 0.0687
# Epoch 191/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0218 - val_loss: 0.0697
# Epoch 192/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0217 - val_loss: 0.0687
# Epoch 193/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0217 - val_loss: 0.0709
# Epoch 194/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0216 - val_loss: 0.0709
# Epoch 195/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0215 - val_loss: 0.0711
# Epoch 196/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0220 - val_loss: 0.0709
# Epoch 197/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0221 - val_loss: 0.0711
# Epoch 198/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0220 - val_loss: 0.0697
# Epoch 199/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0218 - val_loss: 0.0681
# Epoch 200/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0219 - val_loss: 0.0685
# Epoch 201/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0216 - val_loss: 0.0685
# Epoch 202/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0217 - val_loss: 0.0675
# Epoch 203/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0215 - val_loss: 0.0655
# Epoch 204/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0214 - val_loss: 0.0671
# Epoch 205/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0213 - val_loss: 0.0675
# Epoch 206/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0216 - val_loss: 0.0681
# Epoch 207/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0217 - val_loss: 0.0665
# Epoch 208/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0215 - val_loss: 0.0679
# Epoch 209/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0214 - val_loss: 0.0676
# Epoch 210/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0217 - val_loss: 0.0660
# Epoch 211/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0216 - val_loss: 0.0664
# Epoch 212/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0213 - val_loss: 0.0678
# Epoch 213/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0213 - val_loss: 0.0675
# Epoch 214/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0214 - val_loss: 0.0690
# Epoch 215/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0213 - val_loss: 0.0685
# Epoch 216/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0213 - val_loss: 0.0677
# Epoch 217/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0209 - val_loss: 0.0672
# Epoch 218/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0207 - val_loss: 0.0665
# Epoch 219/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0208 - val_loss: 0.0663
# Epoch 220/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0205 - val_loss: 0.0666
# Epoch 221/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0208 - val_loss: 0.0668
# Epoch 222/500
# 2/2 [==============================] - 4s 2s/step - loss: 0.0204 - val_loss: 0.0683
# Epoch 223/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0205 - val_loss: 0.0685
# Epoch 224/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0204 - val_loss: 0.0677
# Epoch 225/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0207 - val_loss: 0.0659
# Epoch 226/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0204 - val_loss: 0.0675
# Epoch 227/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0204 - val_loss: 0.0645
# Epoch 228/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0205 - val_loss: 0.0653
# Epoch 229/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0205 - val_loss: 0.0657
# Epoch 230/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0205 - val_loss: 0.0650
# Epoch 231/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0204 - val_loss: 0.0649
# Epoch 232/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0202 - val_loss: 0.0654
# Epoch 233/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0203 - val_loss: 0.0656
# Epoch 234/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0202 - val_loss: 0.0648
# Epoch 235/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0205 - val_loss: 0.0660
# Epoch 236/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0202 - val_loss: 0.0659
# Epoch 237/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0201 - val_loss: 0.0641
# Epoch 238/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0201 - val_loss: 0.0643
# Epoch 239/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0203 - val_loss: 0.0660
# Epoch 240/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0204 - val_loss: 0.0637
# Epoch 241/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0205 - val_loss: 0.0609
# Epoch 242/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0208 - val_loss: 0.0566
# Epoch 243/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0203 - val_loss: 0.0588
# Epoch 244/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0203 - val_loss: 0.0533
# Epoch 245/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0204 - val_loss: 0.0517
# Epoch 246/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0204 - val_loss: 0.0496
# Epoch 247/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0204 - val_loss: 0.0496
# Epoch 248/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0201 - val_loss: 0.0522
# Epoch 249/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0200 - val_loss: 0.0560
# Epoch 250/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0201 - val_loss: 0.0534
# Epoch 251/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0199 - val_loss: 0.0561
# Epoch 252/500
# 2/2 [==============================] - 7s 4s/step - loss: 0.0197 - val_loss: 0.0576
# Epoch 253/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0197 - val_loss: 0.0570
# Epoch 254/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0199 - val_loss: 0.0598
# Epoch 255/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0196 - val_loss: 0.0584
# Epoch 256/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0198 - val_loss: 0.0610
# Epoch 257/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0228 - val_loss: 0.0435
# Epoch 258/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0216 - val_loss: 0.0330
# Epoch 259/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0211 - val_loss: 0.0323
# Epoch 260/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0213 - val_loss: 0.0370
# Epoch 261/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0213 - val_loss: 0.0396
# Epoch 262/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0214 - val_loss: 0.0405
# Epoch 263/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0214 - val_loss: 0.0388
# Epoch 264/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0216 - val_loss: 0.0393
# Epoch 265/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0219 - val_loss: 0.0408
# Epoch 266/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0217 - val_loss: 0.0390
# Epoch 267/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0222 - val_loss: 0.0596
# Epoch 268/500
# 2/2 [==============================] - 7s 4s/step - loss: 0.0221 - val_loss: 0.0720
# Epoch 269/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0220 - val_loss: 0.0695
# Epoch 270/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0220 - val_loss: 0.0594
# Epoch 271/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0219 - val_loss: 0.0527
# Epoch 272/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0218 - val_loss: 0.0443
# Epoch 273/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0221 - val_loss: 0.0381
# Epoch 274/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0215 - val_loss: 0.0353
# Epoch 275/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0214 - val_loss: 0.0368
# Epoch 276/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0211 - val_loss: 0.0403
# Epoch 277/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0210 - val_loss: 0.0469
# Epoch 278/500
# 2/2 [==============================] - 7s 4s/step - loss: 0.0207 - val_loss: 0.0472
# Epoch 279/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0209 - val_loss: 0.0497
# Epoch 280/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0207 - val_loss: 0.0527
# Epoch 281/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0205 - val_loss: 0.0467
# Epoch 282/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0202 - val_loss: 0.0473
# Epoch 283/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0200 - val_loss: 0.0510
# Epoch 284/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0199 - val_loss: 0.0490
# Epoch 285/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0198 - val_loss: 0.0501
# Epoch 286/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0194 - val_loss: 0.0543
# Epoch 287/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0193 - val_loss: 0.0535
# Epoch 288/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0191 - val_loss: 0.0543
# Epoch 289/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0193 - val_loss: 0.0570
# Epoch 290/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0190 - val_loss: 0.0539
# Epoch 291/500
# 2/2 [==============================] - 8s 3s/step - loss: 0.0193 - val_loss: 0.0557
# Epoch 292/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0191 - val_loss: 0.0574
# Epoch 293/500
# 2/2 [==============================] - 7s 3s/step - loss: 0.0190 - val_loss: 0.0563
# Epoch 294/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0193 - val_loss: 0.0576
# Epoch 295/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0188 - val_loss: 0.0577
# Epoch 296/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0192 - val_loss: 0.0557
# Epoch 297/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0189 - val_loss: 0.0525
# Epoch 298/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0189 - val_loss: 0.0512
# Epoch 299/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0186 - val_loss: 0.0519
# Epoch 300/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0187 - val_loss: 0.0500
# Epoch 301/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0186 - val_loss: 0.0497
# Epoch 302/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0187 - val_loss: 0.0524
# Epoch 303/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0190 - val_loss: 0.0534
# Epoch 304/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0190 - val_loss: 0.0491
# Epoch 305/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0192 - val_loss: 0.0502
# Epoch 306/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.
500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0163 - val_loss: 0.0419
# Epoch 437/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0165 - val_loss: 0.0420
# Epoch 438/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0167 - val_loss: 0.0372
# Epoch 439/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0164 - val_loss: 0.0338
# Epoch 440/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0163 - val_loss: 0.0335
# Epoch 441/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0164 - val_loss: 0.0332
# Epoch 442/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0163 - val_loss: 0.0344
# Epoch 443/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0165 - val_loss: 0.0365
# Epoch 444/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0164 - val_loss: 0.0373
# Epoch 445/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0163 - val_loss: 0.0342
# Epoch 446/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0164 - val_loss: 0.0356
# Epoch 447/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0161 - val_loss: 0.0385
# Epoch 448/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0163 - val_loss: 0.0412
# Epoch 449/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0407
# Epoch 450/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0161 - val_loss: 0.0394
# Epoch 451/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0425
# Epoch 452/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0172 - val_loss: 0.0335
# Epoch 453/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0166 - val_loss: 0.0307
# Epoch 454/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0167 - val_loss: 0.0305
# Epoch 455/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0169 - val_loss: 0.0350
# Epoch 456/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0168 - val_loss: 0.0288
# Epoch 457/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0168 - val_loss: 0.0300
# Epoch 458/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0168 - val_loss: 0.0363
# Epoch 459/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0170 - val_loss: 0.0405
# Epoch 460/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0167 - val_loss: 0.0386
# Epoch 461/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0165 - val_loss: 0.0336
# Epoch 462/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0165 - val_loss: 0.0314
# Epoch 463/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0165 - val_loss: 0.0290
# Epoch 464/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0164 - val_loss: 0.0278
# Epoch 465/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0278
# Epoch 466/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0284
# Epoch 467/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0162 - val_loss: 0.0304
# Epoch 468/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0168 - val_loss: 0.0324
# Epoch 469/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0160 - val_loss: 0.0352
# Epoch 470/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0379
# Epoch 471/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0347
# Epoch 472/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0159 - val_loss: 0.0349
# Epoch 473/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0369
# Epoch 474/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0353
# Epoch 475/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0334
# Epoch 476/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0330
# Epoch 477/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0162 - val_loss: 0.0311
# Epoch 478/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0300
# Epoch 479/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0160 - val_loss: 0.0314
# Epoch 480/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0160 - val_loss: 0.0310
# Epoch 481/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0312
# Epoch 482/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0164 - val_loss: 0.0315
# Epoch 483/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0286
# Epoch 484/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0302
# Epoch 485/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0160 - val_loss: 0.0296
# Epoch 486/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0291
# Epoch 487/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0160 - val_loss: 0.0315
# Epoch 488/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0161 - val_loss: 0.0292
# Epoch 489/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0161 - val_loss: 0.0288
# Epoch 490/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0307
# Epoch 491/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0299
# Epoch 492/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0158 - val_loss: 0.0312
# Epoch 493/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0324
# Epoch 494/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0162 - val_loss: 0.0296
# Epoch 495/500
# 2/2 [==============================] - 9s 4s/step - loss: 0.0161 - val_loss: 0.0301
# Epoch 496/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0299
# Epoch 497/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0303
# Epoch 498/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0157 - val_loss: 0.0302
# Epoch 499/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0158 - val_loss: 0.0307
# Epoch 500/500
# 2/2 [==============================] - 8s 4s/step - loss: 0.0159 - val_loss: 0.0309

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Image Clustering

# %%
decoded_imgs = autoencoder.predict(X_test)

# %%
encoder2 = tf.keras.models.Model(input_img,encoder_out)
decoded = encoder2.predict(X_test)

# %%
print(decoded_imgs[0]-decoded_imgs[1])
plt.imshow(decoded_imgs[0])
# Out:
# [[[ 0.1424925   0.17277056  0.17932314]
#   [ 0.1633043   0.18695384  0.20677766]
#   [ 0.1498296   0.17646894  0.20106146]
#   ...
#   [ 0.15348345  0.10906917  0.06745622]
#   [ 0.2022416   0.16318655  0.11812913]
#   [ 0.17736858  0.12130886  0.11019319]]
#
#  [[ 0.17497513  0.19770843  0.22361302]
#   [ 0.21155912  0.22112066  0.24575436]
#   [ 0.17699751  0.19590253  0.23652422]
#   ...
#   [ 0.1953471   0.13545328  0.0956111 ]
#   [ 0.25538418  0.18954605  0.14070544]
#   [ 0.2517243   0.18104595  0.16163155]]
#
#  [[ 0.16108361  0.18510258  0.20710957]
#   [ 0.18481004  0.20261633  0.2183603 ]
#   [ 0.14873913  0.17111516  0.19301823]
#   ...
#   [ 0.17847773  0.12410551  0.07246524]
#   [ 0.2547173   0.19968313  0.12593502]
#   [ 0.25004846  0.174954    0.1521573 ]]
#
#  ...
#
#  [[-0.00202921  0.02519676  0.0446032 ]
#   [ 0.01056615  0.03483978  0.04777011]
#   [ 0.01044208  0.02822664  0.04465684]
#   ...
#   [ 0.06229544  0.08315754  0.10982469]
#   [ 0.07681486  0.10332105  0.11425719]
#   [ 0.07330063  0.10173231  0.10851425]]
#
#  [[ 0.00222361  0.02408832  0.04141358]
#   [ 0.01102081  0.03404337  0.0477601 ]
#   [ 0.00935879  0.03495872  0.04821494]
#   ...
#   [ 0.07520518  0.09546986  0.10540366]
#   [ 0.08024499  0.09829411  0.09674522]
#   [ 0.08266324  0.1011866   0.10273832]]
#
#  [[ 0.00844961  0.02327883  0.02946743]
#   [ 0.01747912  0.0283516   0.03527185]
#   [ 0.0164656   0.0265089   0.03348359]
#   ...
#   [ 0.08396539  0.09726161  0.1016686 ]
#   [ 0.09059915  0.09184226  0.09159476]
#   [ 0.08390206  0.09220988  0.09663978]]]

# %%
#an attempt to reduce the dimensions so that k-means clustering can work better
pca = PCA(n_components=15)
principalComponents = pca.fit_transform(decoded)

# %%
#K-means
km=KMeans(n_clusters=10,init='k-means++',max_iter=1000)
clustered_images = km.fit_predict(principalComponents)

# %%
for cluster in range(10):
    print('cluster: ', cluster)
    a = np.array(Y_test[np.where(clustered_images == cluster)])
    print(np.bincount(a[:,0]))
    print("Probable cluster label : ",np.argmax(np.bincount(a[:,0])))
# Out:
# cluster:  0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d22bb768c41a> in <module>
#       1 for cluster in range(10):
#       2     print('cluster: ', cluster)
# ----> 3     a = np.array(Y_test[np.where(clustered_images == cluster)])
#       4     print(np.bincount(a[:,0]))
#       5     print("Probable cluster label : ",np.argmax(np.bincount(a[:,0])))
#
# NameError: name 'Y_test' is not defined

# %%
copy=clustered_images
decoded_imgs.shape
print(copy)
# Out:
# [9 7 2 2 5 9 1 4 0 8 0 5 5 9 7 8 5 5 9 1 1 4 5 0 5 1 5 1 1 0 4 2 9 5 1 5 8
#  5 7 5 1 5 1 4 1 0 5 9 1 0 1 0 2 5 5 1 2 8 1 4 2 0 9 7 8 0 5 0 1 8 5 9 8 4
#  8 1 6 4 5 5 5 5 5 5 5 5 9 0 2 1 6 9 5 7 7 9 2 7 7 1 1 9 0 3 4 8 2 5 9 4 4
#  4 7 5 9 7 9 9 0 4 1 4 1 1 1 5 4 1 9 1 9 8 1 8 6 2 5 7 8 2 3 4 7 0 8 8 8 8
#  8 8 8 8 4 9 4 0 7 6 6 5 5 5 4 8 3 8 6 5 5 1 9 7 7 4 5 4 1 5 8 5 6 4 7 6 6
#  6 6 6 6 6 6 6 6 1 2 9 9 1 0 8 9 7 2 0 8 5 1 3 4 1 0 1 2 2 2 2 2 2 2 2 2 2
#  2 4 3 1 0 8 9 1 8 7 8 5 7 0 0 5 1 7 8 9 1 0 9 4 9 4 9 4 6 7 5 1 0 5 1 0 8
#  2 4 0 6 4 1 9 4 1 7 4 0 8 9 9 9 7 4]

# %%
for i in range(10):
    n = 10
    count = 0 
    print("Class ",i)
    indices = np.array(np.where(copy==i))
    plt.figure(figsize=(20, 4))
    for j in range(n):
        # display original
        pos = random.randint(0,np.size(indices))
        ax = plt.subplot(2, n,j + 1)
        plt.imshow(X_test[pos].reshape(32,32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, j + 1 + n)
        plt.imshow(decoded_imgs[pos].reshape(32,32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        count+=1
    plt.show()
# Out:
# Class  0
# Class  1
# Class  2
# Class  3
# Class  4
# Class  5
# Class  6
# Class  7
# Class  8
# Class  9

# %% [markdown]
# The results of K-means is not really satisfactory. The images are more or less evenly distributed with no real majority in the cluster(>50% of the cluster size).There are a few classes that have not been represented.Perhaps using a more robust clustering algorithm for images might be needed.There is a major scope for improvement.

# %%
# Plot the clusters

import matplotlib.pyplot as plt

#filter rows of original data
filtered_label0 = principalComponents[clustered_images == 0]
filtered_label1 = principalComponents[clustered_images == 1]
filtered_label2 = principalComponents[clustered_images == 2]
filtered_label3 = principalComponents[clustered_images == 3]
filtered_label4 = principalComponents[clustered_images == 4]
filtered_label5 = principalComponents[clustered_images == 5]
filtered_label6 = principalComponents[clustered_images == 6]


#plotting the results

plt.scatter(km.cluster_centers_[:, 0], 
            km.cluster_centers_[:, 1], 
            s=100,                             # Set centroid size
            c='red')                           # Set centroid color


#Plotting the results
plt.scatter(filtered_label0[:,0] , filtered_label0[:,1] , color = 'blue')
plt.scatter(filtered_label1[:,0] , filtered_label1[:,1] , color = 'black')
plt.scatter(filtered_label2[:,0] , filtered_label2[:,1] , color = 'yellow')
plt.scatter(filtered_label3[:,0] , filtered_label3[:,1] , color = 'orange')
plt.scatter(filtered_label4[:,0] , filtered_label4[:,1] , color = 'cyan')
plt.scatter(filtered_label5[:,0] , filtered_label5[:,1] , color = 'green')
plt.scatter(filtered_label6[:,0] , filtered_label6[:,1] , color = 'pink')


plt.show()
